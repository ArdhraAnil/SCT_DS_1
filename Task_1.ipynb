# %% [markdown]
# <a href="https://colab.research.google.com/github/ArdhraAnil/SCT_DS_1/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/1.1 - India_Historical_Population_Density_Data.csv")
df
# Out:
#     Unnamed: 0  year popu1ation_growth_rate  Population_Density growth_rate
# 0            0  2024          1,441,719,852              438.58       0.92%
# 1            1  2023          1,428,627,663              434.60       0.81%
# 2            2  2022          1,417,173,173              431.11       0.68%
# 3            3  2021          1,407,563,842              428.19       0.80%
# 4            4  2020          1,396,387,127              424.79       0.96%
# ..         ...   ...                    ...                 ...         ...
# 70          70  1954            389,731,406              118.56       2.23%
# 71          71  1953            381,227,705              115.97       2.21%
# 72          72  1952            372,997,188              113.47       2.21%
# 73          73  1951            364,922,360              111.01       2.21%
# 74          74  1950            357,021,100              108.61       0.00%
#
# [75 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.bar(df["year"],df["popu1ation_growth_rate"],color="blue")
plt.xlabel("year")
plt.ylabel("population")
plt.title("population density")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.hist(df["popu1ation_growth_rate"],bins=10,color="blue",edgecolor='black')
plt.xlabel("population density")
plt.ylabel("frequency")
plt.title("distribution of population density")
plt.show()
